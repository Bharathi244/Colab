# %% [markdown]
# <a href="https://colab.research.google.com/github/Bharathi244/Colab/blob/main/TurboDetector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install keras==2.0.3

# %%
! git clone https://github.com/JayaasreeA/Turbo.git

# %%
# %cd Turbo/
# Out:
# /content/Turbo

# %%
! python train_frcnn.py -o simple -p annotate.txt

# %%
! python test_frcnn.py -p test_images
# Out:
# Streaming output truncated to the last 5000 lines.
# res5c_branch2c/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:GPU:0
# 2021-06-14 14:01:57.341029: I tensorflow/core/common_runtime/placer.cc:114] res5c_branch2c/random_normal/RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:GPU:0
# res5c_branch2c/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2021-06-14 14:01:57.341054: I tensorflow/core/common_runtime/placer.cc:114] res5c_branch2c/random_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# res5c_branch2c/random_normal: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# 2021-06-14 14:01:57.341074: I tensorflow/core/common_runtime/placer.cc:114] res5c_branch2c/random_normal: (Add): /job:localhost/replica:0/task:0/device:GPU:0
# res5c_branch2c/kernel: (VariableV2): /job:localhost/replica:0/task:0/device:GPU:0
# ...
